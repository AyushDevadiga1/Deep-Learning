# %%
# In this notebook we will look at how to find the best model parameters for our problem with the help of keras_tuner

# %%
# Now let's all the necessary libraries here 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

import tensorflow as tf
import keras 
import keras_tuner as kt

from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Input,Activation
from keras.layers import Dropout,Dense,BatchNormalization

import os
# Suppress TensorFlow logging (0 = all logs, 1 = hide INFO, 2 = hide WARNING, 3 = hide ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
X,y = make_moons(
                    n_samples = 300,
                    noise = 0.15,
                    random_state=40
)

# %%
plt.figure(figsize=(12,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='Dark2',edgecolors="#36503F")
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.title('Classification Dataset on two features')
plt.show()

# %%
# Now split them again intro training and test set 
X_train,X_test,y_train,y_test = train_test_split(
                                                    X,y,
                                                    test_size=0.2,
                                                    random_state=40
)

# %%
# Template
'''
def build_model(hp):
    model = keras.Sequential()
    

    num_layers = hp.Int('num_layers', min_value=1, max_value=4, default=2)
    
    for i in range(num_layers):
    
        units = hp.Int(f'units_{i}', min_value=32, max_value=256, step=32)
        activation = hp.Choice(f'activation_{i}', values=['relu', 'tanh', 'elu'])
        
        if i == 0:
            model.add(Input(shape=(X.shape[1],)))
            model.add(Dense(units=units))
            model.add(Activation(activation))
        else:
            model.add(Dense(units=units))
            model.add(Activation(activation))
            
        dropout_rate = hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1)
        model.add(Dropout(rate=dropout_rate))
        
    model.add(Dense(1)) 
    model.add(Activation('sigmoid'))

    learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

'''
# Out:
# "\ndef build_model(hp):\n    model = keras.Sequential()\n    \n\n    num_layers = hp.Int('num_layers', min_value=1, max_value=4, default=2)\n    \n    for i in range(num_layers):\n    \n        units = hp.Int(f'units_{i}', min_value=32, max_value=256, step=32)\n        activation = hp.Choice(f'activation_{i}', values=['relu', 'tanh', 'elu'])\n        \n        if i == 0:\n            model.add(Input(shape=(X.shape[1],)))\n            model.add(Dense(units=units))\n            model.add(Activation(activation))\n        else:\n            model.add(Dense(units=units))\n            model.add(Activation(activation))\n            \n        dropout_rate = hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1)\n        model.add(Dropout(rate=dropout_rate))\n        \n    model.add(Dense(1)) \n    model.add(Activation('sigmoid'))\n\n    learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])\n    \n    model.compile(\n        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),\n        loss='binary_crossentropy',\n        metrics=['accuracy']\n    )\n    return model\n\n"

# %%
# Basically to tune the model we need to pass a build_model function to the tuner with params as hp
# We can here specify any speicic param to search or multiple params at once
# There is gridsearch , randomsearch and hyperband 
# For convenience I will use hyperband here

def build_model(hp):

    # Instantiate the model
    model = Sequential()

    # Now we will also do a search for the perfect no of layers as well with no of neurons per layer

    num_layers = hp.Int(
                            'hidden_layers',
                            min_value = 2,
                            max_value = 10,
                            step = 1
    )

    # I explicitly set this cause I want to tune differnt no of neurons for each layer
    for i in range(num_layers) : 

        # Instantiate the search variable
        neuron_units = hp.Int(  
                                f'hidden_units_{i}', # The name for these search
                                min_value=2, # The lower_boundary
                                max_value=26, # The upper_boundary
                                step=2 # Steps = 2,4,6...26
                            ) 

        model.add(Dense(neuron_units))
        model.add(Activation('tanh'))

    # Output layer 
    model.add(Dense(1)) 
    model.add(Activation('sigmoid'))

    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# Hyperband cuts poorly performing trials early to save time
tuner = kt.Hyperband(
    hypermodel=build_model,                           # Pass the function containing the model to search
    objective='val_accuracy',                         # Target metric to maximize/minimize depending on the problem
    max_epochs=20,                                    # Max epochs for a single model
    factor=3,                                         # Reduction factor for resource allocation
    directory='keras_tuner_dir',                      # Folder where progress logs are saved
    project_name='classification_on_moons_tuning_layers_and_nodes'            # Sub-folder name
)

# %%
# 1. Define an EarlyStopping callback to maximize efficiency
stop_early = EarlyStopping(
    monitor='val_loss',             # Which value to look for convergence early
    patience=5,                     # No of values to wait until declaring converged
    restore_best_weights=True
)

# 2. Launch the search execution loop - To initiate the search
tuner.search(
    X_train, y_train,                   # The variables to train model
    # epochs=50,                          # No of epochs # Either leave this or keep this = max_epochs in the tuner 
    validation_data=(X_test,y_test),    # Validation set 
    callbacks=[stop_early]              # Pass the EarlyStopping function here 
)
# Out:
# Trial 30 Complete [00h 00m 08s]
# val_accuracy: 0.8833333253860474
#
# Best val_accuracy So Far: 0.8999999761581421
# Total elapsed time: 00h 03m 43s

# %%
tuner.results_summary(num_trials=1) # Best model_summary
# Out:
# Results summary
# Results in keras_tuner_dir/classification_on_moons_tuning_layers_and_nodes
# Showing 1 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0000 summary
# Hyperparameters:
# hidden_layers: 5
# hidden_units_0: 12
# hidden_units_1: 14
# tuner/epochs: 3
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# hidden_units_2: 2
# hidden_units_3: 2
# hidden_units_4: 2
# Score: 0.8999999761581421

# %%
# 1. Extract the top set of hyperparameters found during the search
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# 2. Automatically rebuild the exact winning architecture
best_model = tuner.hypermodel.build(best_hps)

# %%
# Train the best model on complete dataset 
history = best_model.fit(
    X_train, y_train, 
    epochs=50, 
    validation_data=(X_test, y_test),
    callbacks=[stop_early]
)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - accuracy: 0.8667 - loss: 0.5827 - val_accuracy: 0.8500 - val_loss: 0.5700
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.5543 - val_accuracy: 0.8333 - val_loss: 0.5484
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8667 - loss: 0.5321 - val_accuracy: 0.8333 - val_loss: 0.5313
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8583 - loss: 0.5149 - val_accuracy: 0.8333 - val_loss: 0.5172
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8667 - loss: 0.5007 - val_accuracy: 0.8333 - val_loss: 0.5055
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8542 - loss: 0.4890 - val_accuracy: 0.8333 - val_loss: 0.4951
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8667 - loss: 0.4782 - val_accuracy: 0.8333 - val_loss: 0.4853
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4691 - val_accuracy: 0.8333 - val_loss: 0.4761
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4603 - val_accuracy: 0.8333 - val_loss: 0.4674
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4523 - val_accuracy: 0.8333 - val_loss: 0.4590
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4447 - val_accuracy: 0.8333 - val_loss: 0.4516
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4376 - val_accuracy: 0.8333 - val_loss: 0.4443
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4314 - val_accuracy: 0.8500 - val_loss: 0.4375
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4248 - val_accuracy: 0.8500 - val_loss: 0.4310
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4192 - val_accuracy: 0.8500 - val_loss: 0.4247
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4134 - val_accuracy: 0.8500 - val_loss: 0.4188
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8667 - loss: 0.4084 - val_accuracy: 0.8500 - val_loss: 0.4130
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.4035 - val_accuracy: 0.8500 - val_loss: 0.4081
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3995 - val_accuracy: 0.8500 - val_loss: 0.4027
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3957 - val_accuracy: 0.8667 - val_loss: 0.3986
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3913 - val_accuracy: 0.8667 - val_loss: 0.3948
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8708 - loss: 0.3886 - val_accuracy: 0.8500 - val_loss: 0.3899
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8708 - loss: 0.3842 - val_accuracy: 0.8667 - val_loss: 0.3858
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3814 - val_accuracy: 0.8667 - val_loss: 0.3824
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8708 - loss: 0.3787 - val_accuracy: 0.8667 - val_loss: 0.3791
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8708 - loss: 0.3762 - val_accuracy: 0.8667 - val_loss: 0.3762
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3734 - val_accuracy: 0.8500 - val_loss: 0.3734
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3713 - val_accuracy: 0.8667 - val_loss: 0.3699
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8792 - loss: 0.3689 - val_accuracy: 0.8500 - val_loss: 0.3676
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3671 - val_accuracy: 0.8667 - val_loss: 0.3641
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3649 - val_accuracy: 0.8667 - val_loss: 0.3614
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3634 - val_accuracy: 0.8667 - val_loss: 0.3598
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3619 - val_accuracy: 0.8667 - val_loss: 0.3571
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3599 - val_accuracy: 0.8667 - val_loss: 0.3557
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3588 - val_accuracy: 0.8500 - val_loss: 0.3533
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3581 - val_accuracy: 0.8667 - val_loss: 0.3519
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.3558 - val_accuracy: 0.8833 - val_loss: 0.3490
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3549 - val_accuracy: 0.8667 - val_loss: 0.3477
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3541 - val_accuracy: 0.8667 - val_loss: 0.3448
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3526 - val_accuracy: 0.8667 - val_loss: 0.3441
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3517 - val_accuracy: 0.8667 - val_loss: 0.3431
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3506 - val_accuracy: 0.8667 - val_loss: 0.3418
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3494 - val_accuracy: 0.8667 - val_loss: 0.3395
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3482 - val_accuracy: 0.8833 - val_loss: 0.3384
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3483 - val_accuracy: 0.8667 - val_loss: 0.3374
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3470 - val_accuracy: 0.8667 - val_loss: 0.3363
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3458 - val_accuracy: 0.8833 - val_loss: 0.3357
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3447 - val_accuracy: 0.8833 - val_loss: 0.3344
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3445 - val_accuracy: 0.8667 - val_loss: 0.3351
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3434 - val_accuracy: 0.8667 - val_loss: 0.3339

# %%
# Lets plot the loss on train and test set to look for the performance of the best model
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print(f'The decision boundary made by the model :  \n ')
plt.figure(figsize=(15,5))
plot_decision_regions(X_test, y_test.ravel().astype(int), clf = best_model, legend=2)
plt.show()
# Out:
# The decision boundary made by the model :
#
# 23438/23438 ━━━━━━━━━━━━━━━━━━━━ 33s 1ms/step

# %%
# To be honest our model performance improved a lot just by tweaking these parameters 
# Now The neural network has two tuning parameter and we can clearly see that the descent 
# of the graph clearly increased a lot from just tuning no of neurons for a constant layer
