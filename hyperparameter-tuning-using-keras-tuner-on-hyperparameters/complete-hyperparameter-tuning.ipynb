# %%
# In this notebook we will look at how to find the best model parameters for our problem with the help of keras_tuner

# %%
# Now let's all the necessary libraries here 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

import tensorflow as tf
import keras 
import keras_tuner as kt

from keras.callbacks import EarlyStopping
from keras.optimizers import Adam,SGD,RMSprop
from keras.models import Sequential
from keras.layers import Input,Activation
from keras.layers import Dropout,Dense,BatchNormalization

import os
# Suppress TensorFlow logging (0 = all logs, 1 = hide INFO, 2 = hide WARNING, 3 = hide ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
X,y = make_moons(
                    n_samples = 300,
                    noise = 0.15,
                    random_state=40
)

# %%
plt.figure(figsize=(12,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='Dark2',edgecolors="#36503F")
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.title('Classification Dataset on two features')
plt.show()

# %%
# Now split them again intro training and test set 
X_train,X_test,y_train,y_test = train_test_split(
                                                    X,y,
                                                    test_size=0.2,
                                                    random_state=40
)

# %%
# Template 
'''
# A complete parametric search

def build_model(hp):

    # Instantiate the model
    model = Sequential()

    # Now we will also do a search for the perfect no of layers as well with no of neurons per layer

    num_layers = hp.Int(
                            'hidden_layers',
                            min_value = 2,
                            max_value = 10,
                            step = 1
    )

    # Defining the weight_intializer strategy 
    initializer = hp.Choice(
                                 'kernel_initializer', 
                                 values=['glorot_uniform', 'he_uniform']
                                 )

    # I explicitly set this cause I want to tune differnt no of neurons for each layer
    for i in range(num_layers) : 

        # Instantiate the search variable
        neuron_units = hp.Int(  
                                f'hidden_units_{i}', # The name for these search i
                                min_value=2, # The lower_boundary
                                max_value=26, # The upper_boundary
                                step=2 # Steps = 2,4,6...26
                            ) 
        # Searching for the perfect Activation function
        activation = hp.Choice(
                                f'hidden_activation_{i}' ,     # The name for these search i
                                values = ['relu','tanh','elu'] # The choices stored in values list
        )
        
        model.add(Dense(neuron_units , kernel_initializer=initializer)) # Pass kernel_intializer
        model.add(Activation(activation))

        # This will test rates from 0.0 (off) to 0.5 (drop 50% of connections)
        dropout_rate = hp.Float(
                                    f'dropout_{i}', 
                                    min_value=0.0, 
                                    max_value=0.5, 
                                    step=0.1
                                )
        model.add(Dropout(dropout_rate)) # Also add this dropout after the activation function is defined 

    # Output layer 
    model.add(Dense(1)) 
    model.add(Activation('sigmoid'))

    # Searching for the perfect Activation function
    learning_rate = hp.Choice(
                                'learning_rates' ,         # The name for these search i
                                values = [1e-2, 1e-3, 1e-4] # Differnt values for differnt convergance rate 
        )

    #  A dynamic engine selection choice for optimizers 
    optimizer_name = hp.Choice(
                                'optimizer_engine',
                                values=['adam', 'sgd', 'rmsprop']
                                )
    # A simple if else that passes optimizer according to it's name and also the dynamic learning rate
    if optimizer_name == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer_name == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    else:
        optimizer = RMSprop(learning_rate=learning_rate)

    model.compile(
        optimizer= optimizer, # Passing the choice values
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

'''
# Out:
# "\ndef build_model(hp):\n    model = keras.Sequential()\n    \n\n    num_layers = hp.Int('num_layers', min_value=1, max_value=4, default=2)\n    \n    for i in range(num_layers):\n    \n        units = hp.Int(f'units_{i}', min_value=32, max_value=256, step=32)\n        activation = hp.Choice(f'activation_{i}', values=['relu', 'tanh', 'elu'])\n        \n        if i == 0:\n            model.add(Input(shape=(X.shape[1],)))\n            model.add(Dense(units=units))\n            model.add(Activation(activation))\n        else:\n            model.add(Dense(units=units))\n            model.add(Activation(activation))\n            \n        dropout_rate = hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1)\n        model.add(Dropout(rate=dropout_rate))\n        \n    model.add(Dense(1)) \n    model.add(Activation('sigmoid'))\n\n    learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])\n    \n    model.compile(\n        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),\n        loss='binary_crossentropy',\n        metrics=['accuracy']\n    )\n    return model\n\n"

# %%
# A complete parametric search

def build_model(hp):

    # Instantiate the model
    model = Sequential()

    # Now we will also do a search for the perfect no of layers as well with no of neurons per layer

    num_layers = hp.Int(
                            'hidden_layers',
                            min_value = 2,
                            max_value = 10,
                            step = 1
    )

    # Defining the weight_intializer strategy 
    initializer = hp.Choice(
                                 'kernel_initializer', 
                                 values=['glorot_uniform', 'he_uniform']
                                 )

    # I explicitly set this cause I want to tune differnt no of neurons for each layer
    for i in range(num_layers) : 

        # Instantiate the search variable
        neuron_units = hp.Int(  
                                f'hidden_units_{i}', # The name for these search i
                                min_value=2, # The lower_boundary
                                max_value=26, # The upper_boundary
                                step=2 # Steps = 2,4,6...26
                            ) 
        # Searching for the perfect Activation function
        activation = hp.Choice(
                                f'hidden_activation_{i}' ,     # The name for these search i
                                values = ['relu','tanh','elu'] # The choices stored in values list
        )
        
        model.add(Dense(neuron_units , kernel_initializer=initializer)) # Pass kernel_intializer
        model.add(Activation(activation))

        # This will test rates from 0.0 (off) to 0.5 (drop 50% of connections)
        dropout_rate = hp.Float(
                                    f'dropout_{i}', 
                                    min_value=0.0, 
                                    max_value=0.5, 
                                    step=0.1
                                )
        model.add(Dropout(dropout_rate)) # Also add this dropout after the activation function is defined 

    # Output layer 
    model.add(Dense(1)) 
    model.add(Activation('sigmoid'))

    # Searching for the perfect Activation function
    learning_rate = hp.Choice(
                                'learning_rates' ,         # The name for these search i
                                values = [1e-2, 1e-3, 1e-4] # Differnt values for differnt convergance rate 
        )

    #  A dynamic engine selection choice for optimizers 
    optimizer_name = hp.Choice(
                                'optimizer_engine',
                                values=['adam', 'sgd', 'rmsprop']
                                )
    # A simple if else that passes optimizer according to it's name and also the dynamic learning rate
    if optimizer_name == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer_name == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    else:
        optimizer = RMSprop(learning_rate=learning_rate)

    model.compile(
        optimizer= optimizer, # Passing the choice values
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# Hyperband cuts poorly performing trials early to save time
tuner = kt.Hyperband(
    hypermodel=build_model,                           # Pass the function containing the model to search
    objective='val_accuracy',                         # Target metric to maximize/minimize depending on the problem
    max_epochs=20,                                    # Max epochs for a single model
    factor=3,                                         # Reduction factor for resource allocation
    directory='keras_tuner_dir',                      # Folder where progress logs are saved
    project_name='classification_on_moons_complete'          
)

# %%
# 1. Define an EarlyStopping callback to maximize efficiency
stop_early = EarlyStopping(
    monitor='val_loss',             # Which value to look for convergence early
    patience=5,                     # No of values to wait until declaring converged
    restore_best_weights=True
)

# 2. Launch the search execution loop - To initiate the search
tuner.search(
    X_train, y_train,                   # The variables to train model
    # epochs=50,                          # No of epochs # Either leave this or keep this = max_epochs in the tuner 
    validation_data=(X_test,y_test),    # Validation set 
    callbacks=[stop_early]              # Pass the EarlyStopping function here 
)
# Out:
# Trial 30 Complete [00h 00m 12s]
# val_accuracy: 0.7833333611488342
#
# Best val_accuracy So Far: 0.949999988079071
# Total elapsed time: 00h 05m 56s

# %%
tuner.results_summary(num_trials=1) # Best model_summary
# Out:
# Results summary
# Results in keras_tuner_dir/classification_on_moons_complete
# Showing 1 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0027 summary
# Hyperparameters:
# hidden_layers: 6
# kernel_initializer: he_uniform
# hidden_units_0: 22
# hidden_activation_0: relu
# dropout_0: 0.4
# hidden_units_1: 2
# hidden_activation_1: elu
# dropout_1: 0.4
# learning_rates: 0.01
# optimizer_engine: rmsprop
# hidden_units_2: 2
# hidden_activation_2: elu
# dropout_2: 0.2
# hidden_units_3: 6
# hidden_activation_3: relu
# dropout_3: 0.0
# hidden_units_4: 16
# hidden_activation_4: tanh
# dropout_4: 0.4
# hidden_units_5: 20
# hidden_activation_5: elu
# dropout_5: 0.30000000000000004
# hidden_units_6: 12
# hidden_activation_6: relu
# dropout_6: 0.4
# hidden_units_7: 20
# hidden_activation_7: relu
# dropout_7: 0.4
# hidden_units_8: 18
# hidden_activation_8: relu
# dropout_8: 0.4
# hidden_units_9: 20
# hidden_activation_9: tanh
# dropout_9: 0.1
# tuner/epochs: 20
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.949999988079071

# %%
# 1. Extract the top set of hyperparameters found during the search
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# 2. Automatically rebuild the exact winning architecture
best_model = tuner.hypermodel.build(best_hps)

# %%
# Train the best model on complete dataset 
history = best_model.fit(
    X_train, y_train, 
    epochs=50, 
    validation_data=(X_test, y_test),
    callbacks=[stop_early]
)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 508ms/step - accuracy: 0.4917 - loss: 0.8378 - val_accuracy: 0.5167 - val_loss: 0.6941
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4958 - loss: 0.7681 - val_accuracy: 0.6500 - val_loss: 0.6225
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5875 - loss: 0.6919 - val_accuracy: 0.6500 - val_loss: 0.6163
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5833 - loss: 0.6745 - val_accuracy: 0.6667 - val_loss: 0.5982
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5875 - loss: 0.6749 - val_accuracy: 0.7167 - val_loss: 0.5807
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5833 - loss: 0.6681 - val_accuracy: 0.7167 - val_loss: 0.5576
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5750 - loss: 0.6114 - val_accuracy: 0.7000 - val_loss: 0.5733
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6208 - loss: 0.6462 - val_accuracy: 0.7167 - val_loss: 0.5603
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6375 - loss: 0.6397 - val_accuracy: 0.7167 - val_loss: 0.5549
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6625 - loss: 0.5987 - val_accuracy: 0.7167 - val_loss: 0.5793
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6542 - loss: 0.6204 - val_accuracy: 0.7500 - val_loss: 0.5514
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6458 - loss: 0.5875 - val_accuracy: 0.7500 - val_loss: 0.5118
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6708 - loss: 0.5966 - val_accuracy: 0.7167 - val_loss: 0.5449
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6917 - loss: 0.5531 - val_accuracy: 0.7500 - val_loss: 0.4559
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7292 - loss: 0.5380 - val_accuracy: 0.8667 - val_loss: 0.4004
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7375 - loss: 0.5439 - val_accuracy: 0.8000 - val_loss: 0.4158
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7417 - loss: 0.5074 - val_accuracy: 0.8000 - val_loss: 0.3646
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7458 - loss: 0.4853 - val_accuracy: 0.8667 - val_loss: 0.3138
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7708 - loss: 0.5227 - val_accuracy: 0.8833 - val_loss: 0.3132
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7500 - loss: 0.4768 - val_accuracy: 0.9167 - val_loss: 0.2907
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7542 - loss: 0.5139 - val_accuracy: 0.8833 - val_loss: 0.3646
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7250 - loss: 0.5322 - val_accuracy: 0.8667 - val_loss: 0.3686
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8042 - loss: 0.4441 - val_accuracy: 0.8667 - val_loss: 0.3187
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7208 - loss: 0.5482 - val_accuracy: 0.9167 - val_loss: 0.2983
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7333 - loss: 0.4892 - val_accuracy: 0.9167 - val_loss: 0.2669
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7375 - loss: 0.4958 - val_accuracy: 0.9333 - val_loss: 0.3079
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7792 - loss: 0.4667 - val_accuracy: 0.9167 - val_loss: 0.2448
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7917 - loss: 0.4534 - val_accuracy: 0.9167 - val_loss: 0.2695
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7375 - loss: 0.4918 - val_accuracy: 0.9500 - val_loss: 0.2025
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8042 - loss: 0.4176 - val_accuracy: 0.9333 - val_loss: 0.2101
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7875 - loss: 0.3989 - val_accuracy: 0.8833 - val_loss: 0.1773
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7708 - loss: 0.4403 - val_accuracy: 0.9167 - val_loss: 0.2032
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7583 - loss: 0.4552 - val_accuracy: 0.9333 - val_loss: 0.2520
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7792 - loss: 0.4739 - val_accuracy: 0.9500 - val_loss: 0.2089
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7375 - loss: 0.4648 - val_accuracy: 0.9500 - val_loss: 0.2109
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7792 - loss: 0.4431 - val_accuracy: 0.9500 - val_loss: 0.1724
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7917 - loss: 0.4107 - val_accuracy: 0.9333 - val_loss: 0.1902
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7500 - loss: 0.4332 - val_accuracy: 0.9333 - val_loss: 0.2182
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7750 - loss: 0.4082 - val_accuracy: 0.9500 - val_loss: 0.2125
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7958 - loss: 0.3820 - val_accuracy: 0.9500 - val_loss: 0.1589
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8458 - loss: 0.3588 - val_accuracy: 0.9500 - val_loss: 0.1636
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8167 - loss: 0.3798 - val_accuracy: 0.9333 - val_loss: 0.1644
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7875 - loss: 0.3791 - val_accuracy: 0.9333 - val_loss: 0.1668
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7833 - loss: 0.3603 - val_accuracy: 0.9500 - val_loss: 0.1424
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8000 - loss: 0.3931 - val_accuracy: 0.9667 - val_loss: 0.1763
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7708 - loss: 0.3615 - val_accuracy: 0.9667 - val_loss: 0.1884
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8167 - loss: 0.3322 - val_accuracy: 0.9833 - val_loss: 0.1116
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7875 - loss: 0.3667 - val_accuracy: 0.9667 - val_loss: 0.0928
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8000 - loss: 0.3516 - val_accuracy: 0.9667 - val_loss: 0.1198
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8250 - loss: 0.3473 - val_accuracy: 0.9500 - val_loss: 0.1752

# %%
# Lets plot the loss on train and test set to look for the performance of the best model
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print(f'The decision boundary made by the model :  \n ')
plt.figure(figsize=(15,5))
plot_decision_regions(X_test, y_test.ravel().astype(int), clf = best_model, legend=2)
plt.show()
# Out:
# The decision boundary made by the model :
#
# 23438/23438 ━━━━━━━━━━━━━━━━━━━━ 33s 1ms/step

# %%
# Works fine and maybe actually better generally but cant be more sure cause the dataset is small
# and we may need a bigger dataset for better finetuning tutorial
