# %%
# In this notebook we will look at how to find the best model parameters for our problem with the help of keras_tuner

# %%
# Now let's all the necessary libraries here 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

import tensorflow as tf
import keras 
import keras_tuner as kt

from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Input,Activation
from keras.layers import Dropout,Dense,BatchNormalization

import os
# Suppress TensorFlow logging (0 = all logs, 1 = hide INFO, 2 = hide WARNING, 3 = hide ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
X,y = make_moons(
                    n_samples = 300,
                    noise = 0.15,
                    random_state=40
)

# %%
plt.figure(figsize=(12,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='Dark2',edgecolors="#36503F")
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.title('Classification Dataset on two features')
plt.show()

# %%
# Now split them again intro training and test set 
X_train,X_test,y_train,y_test = train_test_split(
                                                    X,y,
                                                    test_size=0.2,
                                                    random_state=40
)

# %%
# Template
'''
def build_model(hp):
    model = keras.Sequential()
    

    num_layers = hp.Int('num_layers', min_value=1, max_value=4, default=2)
    
    for i in range(num_layers):
    
        units = hp.Int(f'units_{i}', min_value=32, max_value=256, step=32)
        activation = hp.Choice(f'activation_{i}', values=['relu', 'tanh', 'elu'])
        
        if i == 0:
            model.add(Input(shape=(X.shape[1],)))
            model.add(Dense(units=units))
            model.add(Activation(activation))
        else:
            model.add(Dense(units=units))
            model.add(Activation(activation))
            
        dropout_rate = hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1)
        model.add(Dropout(rate=dropout_rate))
        
    model.add(Dense(1)) 
    model.add(Activation('sigmoid'))

    learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

'''
# Out:
# "\ndef build_model(hp):\n    model = keras.Sequential()\n    \n\n    num_layers = hp.Int('num_layers', min_value=1, max_value=4, default=2)\n    \n    for i in range(num_layers):\n    \n        units = hp.Int(f'units_{i}', min_value=32, max_value=256, step=32)\n        activation = hp.Choice(f'activation_{i}', values=['relu', 'tanh', 'elu'])\n        \n        if i == 0:\n            model.add(Input(shape=(X.shape[1],)))\n            model.add(Dense(units=units))\n            model.add(Activation(activation))\n        else:\n            model.add(Dense(units=units))\n            model.add(Activation(activation))\n            \n        dropout_rate = hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1)\n        model.add(Dropout(rate=dropout_rate))\n        \n    model.add(Dense(1)) \n    model.add(Activation('sigmoid'))\n\n    learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])\n    \n    model.compile(\n        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),\n        loss='binary_crossentropy',\n        metrics=['accuracy']\n    )\n    return model\n\n"

# %%
# Basically to tune the model we need to pass a build_model function to the tuner with params as hp
# We can here specify any speicic param to search or multiple params at once
# There is gridsearch , randomsearch and hyperband 
# For convenience I will use hyperband here

def build_model(hp):

    # Instantiate the model
    model = Sequential()

    # Search the perfect no of neurons for two layers 

    num_layers = 2 

    # I explicitly set this cause I want to tune differnt no of neurons for each layer
    for i in range(num_layers) : 

        # Instantiate the search variable
        neuron_units = hp.Int(  
                                f'hidden_units_{i}', # The name for these search
                                min_value=2, # The lower_boundary
                                max_value=26, # The upper_boundary
                                step=2 # Steps = 2,4,6...26
                            ) 

        model.add(Dense(neuron_units))
        model.add(Activation('tanh'))

    # Output layer 
    model.add(Dense(1)) 
    model.add(Activation('sigmoid'))

    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# Hyperband cuts poorly performing trials early to save time
tuner = kt.Hyperband(
    hypermodel=build_model,                           # Pass the function containing the model to search
    objective='val_accuracy',                         # Target metric to maximize/minimize depending on the problem
    max_epochs=20,                                    # Max epochs for a single model
    factor=3,                                         # Reduction factor for resource allocation
    directory='keras_tuner_dir',                      # Folder where progress logs are saved
    project_name='classification_on_moons'            # Sub-folder name
)
# Out:
# I0000 00:00:1780968330.773485      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780968330.780165      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
# 1. Define an EarlyStopping callback to maximize efficiency
stop_early = EarlyStopping(
    monitor='val_loss',             # Which value to look for convergence early
    patience=5,                     # No of values to wait until declaring converged
    restore_best_weights=True
)

# 2. Launch the search execution loop - To initiate the search
tuner.search(
    X_train, y_train,                   # The variables to train model
    # epochs=50,                          # No of epochs # Either leave this or keep this = max_epochs in the tuner 
    validation_data=(X_test,y_test),    # Validation set 
    callbacks=[stop_early]              # Pass the EarlyStopping function here 
)
# Out:
# Trial 30 Complete [00h 00m 06s]
# val_accuracy: 0.8333333134651184
#
# Best val_accuracy So Far: 0.8999999761581421
# Total elapsed time: 00h 02m 20s

# %%
tuner.results_summary(num_trials=1) # Best model_summary
# Out:
# Results summary
# Results in keras_tuner_dir/classification_on_moons
# Showing 1 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0018 summary
# Hyperparameters:
# hidden_units_0: 2
# hidden_units_1: 16
# tuner/epochs: 7
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.8999999761581421

# %%
# 1. Extract the top set of hyperparameters found during the search
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# 2. Automatically rebuild the exact winning architecture
best_model = tuner.hypermodel.build(best_hps)

# %%
# Train the best model on complete dataset 
history = best_model.fit(
    X_train, y_train, 
    epochs=50, 
    validation_data=(X_test, y_test),
    callbacks=[stop_early]
)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8417 - loss: 0.3500 - val_accuracy: 0.8333 - val_loss: 0.3659
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8417 - loss: 0.3472 - val_accuracy: 0.8333 - val_loss: 0.3628
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8458 - loss: 0.3451 - val_accuracy: 0.8333 - val_loss: 0.3595
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8458 - loss: 0.3429 - val_accuracy: 0.8333 - val_loss: 0.3565
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8458 - loss: 0.3409 - val_accuracy: 0.8333 - val_loss: 0.3535
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8458 - loss: 0.3389 - val_accuracy: 0.8333 - val_loss: 0.3505
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8458 - loss: 0.3371 - val_accuracy: 0.8333 - val_loss: 0.3475
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8500 - loss: 0.3352 - val_accuracy: 0.8333 - val_loss: 0.3449
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8500 - loss: 0.3335 - val_accuracy: 0.8333 - val_loss: 0.3425
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8500 - loss: 0.3319 - val_accuracy: 0.8333 - val_loss: 0.3400
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8500 - loss: 0.3305 - val_accuracy: 0.8333 - val_loss: 0.3379
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8542 - loss: 0.3290 - val_accuracy: 0.8333 - val_loss: 0.3353
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8583 - loss: 0.3275 - val_accuracy: 0.8333 - val_loss: 0.3330
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.3263 - val_accuracy: 0.8333 - val_loss: 0.3309
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.3250 - val_accuracy: 0.8333 - val_loss: 0.3291
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.3241 - val_accuracy: 0.8333 - val_loss: 0.3267
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8667 - loss: 0.3227 - val_accuracy: 0.8333 - val_loss: 0.3240
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8667 - loss: 0.3217 - val_accuracy: 0.8333 - val_loss: 0.3217
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8667 - loss: 0.3208 - val_accuracy: 0.8333 - val_loss: 0.3196
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8667 - loss: 0.3198 - val_accuracy: 0.8333 - val_loss: 0.3176
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3186 - val_accuracy: 0.8333 - val_loss: 0.3162
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8708 - loss: 0.3177 - val_accuracy: 0.8333 - val_loss: 0.3147
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8708 - loss: 0.3168 - val_accuracy: 0.8333 - val_loss: 0.3133
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3161 - val_accuracy: 0.8333 - val_loss: 0.3121
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3154 - val_accuracy: 0.8333 - val_loss: 0.3102
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3145 - val_accuracy: 0.8333 - val_loss: 0.3090
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.3138 - val_accuracy: 0.8333 - val_loss: 0.3076
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3131 - val_accuracy: 0.8500 - val_loss: 0.3070
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3124 - val_accuracy: 0.8500 - val_loss: 0.3057
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.3118 - val_accuracy: 0.8500 - val_loss: 0.3041
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.3112 - val_accuracy: 0.8500 - val_loss: 0.3027
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.3107 - val_accuracy: 0.8500 - val_loss: 0.3017
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3100 - val_accuracy: 0.8667 - val_loss: 0.3003
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3095 - val_accuracy: 0.8667 - val_loss: 0.2994
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3092 - val_accuracy: 0.8667 - val_loss: 0.2979
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3084 - val_accuracy: 0.8667 - val_loss: 0.2972
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3081 - val_accuracy: 0.8667 - val_loss: 0.2967
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8792 - loss: 0.3078 - val_accuracy: 0.8667 - val_loss: 0.2952
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8792 - loss: 0.3073 - val_accuracy: 0.8667 - val_loss: 0.2951
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8792 - loss: 0.3074 - val_accuracy: 0.8667 - val_loss: 0.2950
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8833 - loss: 0.3065 - val_accuracy: 0.8667 - val_loss: 0.2936
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8792 - loss: 0.3062 - val_accuracy: 0.8667 - val_loss: 0.2914
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.3058 - val_accuracy: 0.8833 - val_loss: 0.2897
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3053 - val_accuracy: 0.8833 - val_loss: 0.2890
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8750 - loss: 0.3049 - val_accuracy: 0.8833 - val_loss: 0.2885
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.3045 - val_accuracy: 0.8833 - val_loss: 0.2883
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8792 - loss: 0.3045 - val_accuracy: 0.8667 - val_loss: 0.2882
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8792 - loss: 0.3041 - val_accuracy: 0.8667 - val_loss: 0.2876
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8833 - loss: 0.3041 - val_accuracy: 0.8667 - val_loss: 0.2878
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8833 - loss: 0.3040 - val_accuracy: 0.8833 - val_loss: 0.2862

# %%
# Lets plot the loss on train and test set to look for the performance of the best model
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print(f'The decision boundary made by the model :  \n ')
plt.figure(figsize=(15,5))
plot_decision_regions(X_test, y_test.ravel().astype(int), clf = best_model, legend=2)
plt.show()
# Out:
# The decision boundary made by the model :
#
# 23438/23438 ━━━━━━━━━━━━━━━━━━━━ 30s 1ms/step

# %%
# The model performed really well even with just tuning the no of neurons , I think we will achieve greater heights if we tune no of layers next
