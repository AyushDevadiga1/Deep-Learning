# %%
import numpy as np
import keras
from keras.layers import TextVectorization,Flatten,Dense,Embedding,GlobalAveragePooling1D

# %%
data = [
            'wanna catch em all',
            'pokemon!!! GOOOO',
            'Gonna catch em alllll',
            'OH no !!! Pikachu !!!!',
            'This pokemon is crazy strong !!',
            'Ash Ketchum born in Palet Town'
]

# %%
# Also add labels here so we will this dataset as a sample to use for sentiment analysis
labels = np.array([1,1,1,0,0,1])

# %%
# Instantiate the vectorizer layer
vectorizer = TextVectorization(output_sequence_length=10) # The output_sequence_length itself is the padding here 

# Fit our custom data
vectorizer.adapt(data)

# %%
# Now we can get the vocublary using get_vocabulary()
vectorizer.get_vocabulary() 
# The unknown string is "!"
# Out:
# ['',
#  '[UNK]',
#  np.str_('pokemon'),
#  np.str_('em'),
#  np.str_('catch'),
#  np.str_('wanna'),
#  np.str_('town'),
#  np.str_('this'),
#  np.str_('strong'),
#  np.str_('pikachu'),
#  np.str_('palet'),
#  np.str_('oh'),
#  np.str_('no'),
#  np.str_('ketchum'),
#  np.str_('is'),
#  np.str_('in'),
#  np.str_('goooo'),
#  np.str_('gonna'),
#  np.str_('crazy'),
#  np.str_('born'),
#  np.str_('ash'),
#  np.str_('alllll'),
#  np.str_('all')]

# %%
# To peek on what was the index assigned for each we do :
word_to_id = {word:idx for idx,word in enumerate(vectorizer.get_vocabulary())}

print("---Word to Integer Mapping---")
for word,idx in word_to_id.items():
    print(f'{word} : {idx}')
# Out:
# ---Word to Integer Mapping---
#  : 0
# [UNK] : 1
# pokemon : 2
# em : 3
# catch : 4
# wanna : 5
# town : 6
# this : 7
# strong : 8
# pikachu : 9
# palet : 10
# oh : 11
# no : 12
# ketchum : 13
# is : 14
# in : 15
# goooo : 16
# gonna : 17
# crazy : 18
# born : 19
# ash : 20
# alllll : 21
# all : 22

# %%
# Get the vocab size  : 
vocab_size = len(vectorizer.get_vocabulary()) + 1
vocab_size
# Out:
# 24

# %%
# Get the padded sequnces from fitting vectorizing our data now
sequences = vectorizer(data)

# %%
# Now we build the model for Integer Encodding

model = keras.Sequential(
    [
        keras.Input(shape=(10,)), # The input shape is same as what we passed above in padding
        Flatten(), # Flattent the layers
        Dense(10,activation='relu'), # Set the Hidden Layers
        Dense(1,activation='sigmoid')  # Set the Output Layer
    ]
)

# %%
# Inspect the model params
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 121 (484.00 B)
#  Trainable params: 121 (484.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# Train the model :
model.fit(sequences,labels,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6667 - loss: 1.7200
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.6667 - loss: 1.6935
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6667 - loss: 1.6676
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6667 - loss: 1.6424
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.6667 - loss: 1.6179
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.6667 - loss: 1.5941
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6667 - loss: 1.5712
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6667 - loss: 1.5491
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6667 - loss: 1.5279
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6667 - loss: 1.5076

# %%
# As we see there is no accuracy change at all but that's not the point here

# %%
# Evaluate the model
loss,accuracy = model.evaluate(sequences,labels,verbose=0)
print(f'The loss for the model : {loss:.2f}')
print(f'The accuracy for the model : {accuracy:.2f}')
# Out:
# The loss for the model : 1.49
# The accuracy for the model : 0.67

# %%
# We can use the same vectorizer but just now pass on the embeddings layer so now we make it into embeddings
model = keras.Sequential(
    [
        keras.Input(shape=(10,)), 
        Embedding(input_dim=vocab_size,output_dim=2), # Add output_dim , which is a hyperparameter
        GlobalAveragePooling1D(), # Use GlobalAveragePooling instead of Flatten
        Dense(10,activation='relu'), 
        Dense(1,activation='sigmoid') 
    ]
)
model.summary()
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(sequences,labels,epochs=10,verbose=1)
loss,accuracy = model.evaluate(sequences,labels,verbose=0)
print(f'The loss for the model : {loss:.2f}')
print(f'The accuracy for the model : {accuracy:.2f}')
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 10, 2)          │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 2)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
# ...
