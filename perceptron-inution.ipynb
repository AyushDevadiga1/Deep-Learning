# %%
# This basically a practice session notebook on the perceptron concepts learned and to visualize why it does not work 
# on non linear datasets

# %%
# Import Necessities 
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from mlxtend.plotting import plot_decision_regions

from sklearn.datasets import make_classification
from sklearn.datasets import make_circles
from sklearn.linear_model import Perceptron

# %%
# Dataset 1 — Linear 

X_l, y_l = make_classification(
    n_samples=200,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_clusters_per_class=1,
    random_state=42
)

# %%
# Dataset 2 — Non-linear

X_nl, y_nl = make_circles(
    n_samples=200,
    noise=0.1,
    factor=0.5,
    random_state=42
)

# %%
X_l[0]
# Out:
# array([-0.87292898,  0.013042  ])

# %%
# Now let's visualize them both

fig,axes = plt.subplots(1,2,figsize=(15,5))

plt.sca(ax=axes[0])
plt.scatter(X_l[:,0],X_l[:,1],c=y_l,cmap="Accent",edgecolors="#5E5E5E")
plt.xlabel("Feature_1")
plt.ylabel("Feature_2")
plt.title("Linear Data")

plt.sca(ax=axes[1])
plt.scatter(X_nl[:,0],X_nl[:,1],c=y_nl,cmap="Dark2",edgecolors="#434343")
plt.xlabel("Feature_1")
plt.ylabel("Feature_2")
plt.title("Non-Linear Data")

plt.tight_layout()
plt.show()

# %%
# Train model for both the datasets

# %%
p_l = Perceptron()
p_l.fit(X_l,y_l)

p_nl = Perceptron()
p_nl.fit(X_nl,y_nl)
# Out:
# Perceptron()

# %%
# Now lets plot both the model boundaries using ml_extend

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

plt.sca(axes[0])
plot_decision_regions(X_l, y_l, clf=p_l, legend=2)
axes[0].set_title(f"Linear data — Perceptron")
axes[0].set_xlabel("Feature 1")
axes[0].set_ylabel("Feature 2")

plt.sca(axes[1])
plot_decision_regions(X_nl, y_nl, clf=p_nl, legend=2)
axes[1].set_title(f"Non-linear data (circles) — Perceptron ")
axes[1].set_xlabel("Feature 1")
axes[1].set_ylabel("Feature 2")

plt.suptitle("Perceptron: Linear vs Non-linear data", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       1 fig, axes = plt.subplots(1, 2, figsize=(14, 5))
#       2
#       3 plt.sca(axes[0])
# ----> 4 plot_decision_regions(X_l, y_l, clf=p_l, legend=2)
#       5 axes[0].set_title(f"Linear data — Perceptron")
#       6 axes[0].set_xlabel("Feature 1")
#       7 axes[0].set_ylabel("Feature 2")
#
# NameError: name 'p_l' is not defined

# %%
# Hence we concluded that perceptron works the best on linearly seperable data
