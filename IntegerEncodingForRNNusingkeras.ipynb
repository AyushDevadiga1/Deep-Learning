# %%
import numpy as np
import keras
from keras.layers import TextVectorization,Flatten,Dense

# %%
data = [
            'wanna catch em all',
            'pokemon!!! GOOOO',
            'Gonna catch em alllll',
            'OH no !!! Pikachu !!!!',
            'This pokemon is crazy strong !!',
            'Ash Ketchum born in Palet Town'
]

# %%
# Also add labels here so we will this dataset as a sample to use for sentiment analysis
labels = np.array([1,1,1,0,0,1])

# %%
# Instantiate the vectorizer layer
vectorizer = TextVectorization(output_sequence_length=8) # The output_sequence_length itself is the padding here 

# Fit our custom data
vectorizer.adapt(data)

# %%
# Now we can get the vocublary using get_vocabulary()
vectorizer.get_vocabulary() 
# The unknown string is "!"
# Out:
# ['',
#  '[UNK]',
#  np.str_('pokemon'),
#  np.str_('em'),
#  np.str_('catch'),
#  np.str_('wanna'),
#  np.str_('town'),
#  np.str_('this'),
#  np.str_('strong'),
#  np.str_('pikachu'),
#  np.str_('palet'),
#  np.str_('oh'),
#  np.str_('no'),
#  np.str_('ketchum'),
#  np.str_('is'),
#  np.str_('in'),
#  np.str_('goooo'),
#  np.str_('gonna'),
#  np.str_('crazy'),
#  np.str_('born'),
#  np.str_('ash'),
#  np.str_('alllll'),
#  np.str_('all')]

# %%
# Get the padded sequnces from fitting vectorizing our data now
sequences = vectorizer(data)

# %%
# Now we build the model for Integer Encodding

model = keras.Sequential(
    [
        keras.Input(shape=(8,)), # The input shape as 8 , same as what we passed above in padding
        Flatten(), # Flattent the layers
        Dense(4,activation='relu'), # Set the Hidden Layers
        Dense(1,activation='sigmoid')  # Set the Output Layer
    ]
)

# %%
# Compile the model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# Train the model :
model.fit(sequences,labels,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6667 - loss: 2.3254
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6667 - loss: 2.2989
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6667 - loss: 2.2727
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6667 - loss: 2.2466
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6667 - loss: 2.2208
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6667 - loss: 2.1951
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.6667 - loss: 2.1697
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6667 - loss: 2.1446
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6667 - loss: 2.1196
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6667 - loss: 2.0949

# %%
# As we see there is no loss change at all but that's not the point here
