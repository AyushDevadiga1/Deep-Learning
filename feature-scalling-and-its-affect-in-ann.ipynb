# %%
# In many notebooks we bragged and talked about how the model should have the data in same scale for faster convergence and better modelling
# We never knew the why behind it and in this notebook we will try to understand why scalling acts as a plus point for our model

# %%
# Import the necessary libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow
from tensorflow import keras

from keras import Sequential
from keras.layers import Dense,Input

# %%
# Now for this we will be again using the classification dataset - Social_Network_Ads.csv
df = pd.read_csv('Social_Network_Ads.csv',usecols=['Age','EstimatedSalary','Purchased'])

# %%
df.head() # We will be deliberately using these columns as we can clearly see the differnece in scale
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.shape # The shape of the dataset
# Out:
# (400, 3)

# %%
# Now lets visualize this points and its scale using the seaborn scatterplot

plt.figure(figsize=(15,6))
sns.scatterplot(
                    data = df,
                    x = 'Age',
                    y = "EstimatedSalary",
                    hue = 'Purchased'
)
plt.show()

# %%
# We can clearly look at the scale and how distributed are ages estimated salary across age 
# This is a wide space and if we use this dataset as it is model convergence will take a lot time

# %%
# Lets plit the dataset into two and then trainig and tesing set
X,y = df.iloc[:,:-1],df.iloc[:,-1]

# %%
X.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
